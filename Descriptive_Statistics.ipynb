# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
# %matplotlib inline

df = pd.read_excel(r'C:\Users\yunus\OneDrive\Masaüstü\Business Analyst_OESON\Tasks\Case_Study_Neet_Yunus.xlsx', sheet_name='uk_neet')

print(df)
# Out:
#      time_period time_identifier geographic_level country_code  \
# 0           2001   Calendar year         National    K02000001
# 1           2002   Calendar year         National    K02000001
# 2           2002   Calendar year         National    K02000001
# 3           2002   Calendar year         National    K02000001
# 4           2002   Calendar year         National    K02000001
# ..           ...             ...              ...          ...
# 706         2020   Calendar year         National    K02000001
# 707         2020   Calendar year         National    K02000001
# 708         2020   Calendar year         National    K02000001
# 709         2021   Calendar year         National    K02000001
# 710         2021   Calendar year         National    K02000001
#
#        country_name quarter  gender         age         t_neet   t_unemployed  \
# 0    United Kingdom      Q4   Total  Aged 16-24  832756.873878  373303.272835
# ...

# %%
df.columns
# Out:
# Index(['time_period', 'time_identifier', 'geographic_level', 'country_code',
#        'country_name', 'quarter', 'gender', 'age', 't_neet', 't_unemployed',
#        't_economically_inactive', 't_population', 'pt_neet'],
#       dtype='object')

# %%
df.shape
# Out:
# (711, 13)

# %%
df.head()
# Out:
#    time_period time_identifier geographic_level country_code    country_name  \
# 0         2001   Calendar year         National    K02000001  United Kingdom
# 1         2002   Calendar year         National    K02000001  United Kingdom
# 2         2002   Calendar year         National    K02000001  United Kingdom
# 3         2002   Calendar year         National    K02000001  United Kingdom
# 4         2002   Calendar year         National    K02000001  United Kingdom
#
#   quarter gender         age         t_neet   t_unemployed  \
# 0      Q4  Total  Aged 16-24  832756.873878  373303.272835
# 1      Q1  Total  Aged 16-24  859075.189485  374351.165444
# 2      Q2  Total  Aged 16-24  872895.365584  367778.071975
# 3      Q3  Total  Aged 16-24  872845.986921  360805.775134
# 4      Q4  Total  Aged 16-24  836001.538407  354230.610051
#
#    t_economically_inactive  t_population    pt_neet
# 0            459453.601043       6438121  12.934781
# ...

# %%
df.tail()
# Out:
#      time_period time_identifier geographic_level country_code  \
# 706         2020   Calendar year         National    K02000001
# 707         2020   Calendar year         National    K02000001
# 708         2020   Calendar year         National    K02000001
# 709         2021   Calendar year         National    K02000001
# 710         2021   Calendar year         National    K02000001
#
#        country_name quarter  gender         age         t_neet   t_unemployed  \
# 706  United Kingdom      Q2  Female  Aged 18-24  344555.511498  112944.504595
# 707  United Kingdom      Q3  Female  Aged 18-24  317187.687380  104691.140118
# 708  United Kingdom      Q4  Female  Aged 18-24  321889.796496  121573.405063
# 709  United Kingdom      Q1  Female  Aged 18-24  290269.533901  111421.116261
# 710  United Kingdom      Q2  Female  Aged 18-24  263122.157502  104005.133921
#
#      t_economically_inactive  t_population    pt_neet
# 706            231611.006903       2659971  12.953356
# ...

# %%
df['t_neet']
# Out:
# 0      832756.873878
# 1      859075.189485
# 2      872895.365584
# 3      872845.986921
# 4      836001.538407
#            ...
# 706    344555.511498
# 707    317187.687380
# 708    321889.796496
# 709    290269.533901
# 710    263122.157502
# Name: t_neet, Length: 711, dtype: float64

# %%
df.iloc[:3]
# Out:
#    time_period time_identifier geographic_level country_code    country_name  \
# 0         2001   Calendar year         National    K02000001  United Kingdom
# 1         2002   Calendar year         National    K02000001  United Kingdom
# 2         2002   Calendar year         National    K02000001  United Kingdom
#
#   quarter gender         age         t_neet   t_unemployed  \
# 0      Q4  Total  Aged 16-24  832756.873878  373303.272835
# 1      Q1  Total  Aged 16-24  859075.189485  374351.165444
# 2      Q2  Total  Aged 16-24  872895.365584  367778.071975
#
#    t_economically_inactive  t_population    pt_neet
# 0            459453.601043       6438121  12.934781
# 1            484724.024041       6473467  13.270712
# 2            505117.293608       6508963  13.410667

# %%
df.iloc[0:5,8:10]
# Out:
#           t_neet   t_unemployed
# 0  832756.873878  373303.272835
# 1  859075.189485  374351.165444
# 2  872895.365584  367778.071975
# 3  872845.986921  360805.775134
# 4  836001.538407  354230.610051

# %%
df[df['quarter']=='Q4']
# Out:
#      time_period time_identifier geographic_level country_code  \
# 0           2001   Calendar year         National    K02000001
# 4           2002   Calendar year         National    K02000001
# 8           2003   Calendar year         National    K02000001
# 12          2004   Calendar year         National    K02000001
# 16          2005   Calendar year         National    K02000001
# ..           ...             ...              ...          ...
# 692         2016   Calendar year         National    K02000001
# 696         2017   Calendar year         National    K02000001
# 700         2018   Calendar year         National    K02000001
# 704         2019   Calendar year         National    K02000001
# 708         2020   Calendar year         National    K02000001
#
#        country_name quarter  gender         age        t_neet   t_unemployed  \
# 0    United Kingdom      Q4   Total  Aged 16-24  8.327569e+05  373303.272835
# ...

# %%
sorted_data = df.sort_values(by='pt_neet')
sorted_data[:10]
# Out:
#      time_period time_identifier geographic_level country_code  \
# 609         2015   Calendar year         National    K02000001
# 628         2020   Calendar year         National    K02000001
# 622         2019   Calendar year         National    K02000001
# 607         2015   Calendar year         National    K02000001
# 383         2018   Calendar year         National    K02000001
# 608         2015   Calendar year         National    K02000001
# 619         2018   Calendar year         National    K02000001
# 606         2015   Calendar year         National    K02000001
# 629         2020   Calendar year         National    K02000001
# 154         2020   Calendar year         National    K02000001
#
#        country_name quarter  gender         age        t_neet  t_unemployed  \
# 609  United Kingdom      Q4  Female  Aged 16-17  18050.857325   6172.139384
# 628  United Kingdom      Q3  Female  Aged 16-17  19474.560741   7720.603600
# ...

# %%
df.sort_values(by='pt_neet', ascending=False, inplace=True)
df[:5]
# Out:
#      time_period time_identifier geographic_level country_code  \
# 671         2011   Calendar year         National    K02000001
# 670         2011   Calendar year         National    K02000001
# 668         2010   Calendar year         National    K02000001
# 672         2011   Calendar year         National    K02000001
# 667         2010   Calendar year         National    K02000001
#
#        country_name quarter  gender         age         t_neet   t_unemployed  \
# 671  United Kingdom      Q3  Female  Aged 18-24  617492.707062  235353.415706
# 670  United Kingdom      Q2  Female  Aged 18-24  596545.896284  221370.449368
# 668  United Kingdom      Q4  Female  Aged 18-24  590094.155588  215048.932857
# 672  United Kingdom      Q4  Female  Aged 18-24  591632.310552  226303.781301
# 667  United Kingdom      Q3  Female  Aged 18-24  586414.615578  213192.266196
#
#      t_economically_inactive  t_population    pt_neet
# 671            382139.291357       2907617  21.237072
# ...

# %%
print(df)
# Out:
#      time_period time_identifier geographic_level country_code  \
# 671         2011   Calendar year         National    K02000001
# 670         2011   Calendar year         National    K02000001
# 668         2010   Calendar year         National    K02000001
# 672         2011   Calendar year         National    K02000001
# 667         2010   Calendar year         National    K02000001
# ..           ...             ...              ...          ...
# 383         2018   Calendar year         National    K02000001
# 607         2015   Calendar year         National    K02000001
# 622         2019   Calendar year         National    K02000001
# 628         2020   Calendar year         National    K02000001
# 609         2015   Calendar year         National    K02000001
#
#        country_name quarter  gender         age         t_neet   t_unemployed  \
# 671  United Kingdom      Q3  Female  Aged 18-24  617492.707062  235353.415706
# ...

# %%
df.describe()
# Out:
#        time_period        t_neet   t_unemployed  t_economically_inactive  \
# count   711.000000  7.110000e+02     708.000000               711.000000
# mean   2011.126582  4.186552e+05  192192.789228            227254.361908
# std       5.717358  3.197668e+05  154910.364994            183725.569334
# min    2001.000000  1.805086e+04    5618.292182             10961.770286
# 25%    2006.000000  7.367966e+04   46392.908390             35643.859573
# 50%    2011.000000  4.047494e+05  171852.991564            172673.739074
# 75%    2016.000000  5.863212e+05  296332.826263            391219.170573
# max    2021.000000  1.245652e+06  685780.329441            580525.687916
#
#        t_population     pt_neet
# count  7.110000e+02  711.000000
# mean   3.139564e+06   11.525028
# std    2.005260e+06    4.588848
# min    6.787740e+05    2.513298
# 25%    1.458891e+06    7.859475
# 50%    2.880329e+06   12.177595
# 75%    3.683675e+06   15.045352
# max    7.369834e+06   21.237072

# %%
df['t_neet'].skew()
# Out:
# 0.47478914455774274

# %%
df['t_neet'].kurtosis()
# Out:
# -0.696803376548154

# %%
print(df.isnull().sum())
# Out:
# time_period                0
# time_identifier            0
# geographic_level           0
# country_code               0
# country_name               0
# quarter                    0
# gender                     0
# age                        0
# t_neet                     0
# t_unemployed               3
# t_economically_inactive    0
# t_population               0
# pt_neet                    0
# dtype: int64

# %%
df[['t_neet']].plot(kind='bar',color=['green'])

plt.show()

# %%
df
